# %%
import os
from pdfminer.high_level import extract_text

RAW_DIR   = r"D:\Project Penalaran Komputer\Data\raw"
CLEAN_DIR = r"D:\Project Penalaran Komputer\Data\raw_cleaned"

CLEAN_DIR   = "data/raw_cleaned"
os.makedirs(CLEAN_DIR, exist_ok=True)

def pdf_to_txt(pdf_path, txt_path):
    text = extract_text(pdf_path)
    with open(txt_path, "w", encoding="utf-8") as f:
        f.write(text)

def clean_text(text):
    # Contoh cleaning sederhana: hapus header/footer & watermark
    import re
    lines = []
    for line in text.splitlines():
        line = line.strip()
        if not line: 
            continue
        # hapus watermark MA RI
        if line.startswith("Mah") or line.startswith("Direktori"):
            continue
        # hapus nomor halaman
        if re.match(r"^Hal\s*\d+\s+dari", line):
            continue
        lines.append(line)
    return "\n".join(lines)

if __name__ == "__main__":
    # 1) PDF → TXT
    for fn in os.listdir(RAW_DIR):
        if fn.lower().endswith(".pdf"):
            pdf_path = os.path.join(RAW_DIR, fn)
            txt_path = os.path.join(RAW_DIR, fn[:-4] + ".txt")
            pdf_to_txt(pdf_path, txt_path)
            print(f"[PDF→TXT] {pdf_path}")

    # 2) Cleaning
    for fn in os.listdir(RAW_DIR):
        if fn.lower().endswith(".txt"):
            raw_txt = open(os.path.join(RAW_DIR, fn), encoding="utf-8").read()
            cleaned = clean_text(raw_txt)
            with open(os.path.join(CLEAN_DIR, fn), "w", encoding="utf-8") as f:
                f.write(cleaned)
            print(f"[Clean] {fn}")
# Out:
# [PDF→TXT] D:\Project Penalaran Komputer\Data\raw\putusan_100_pid.b_2018_pn_jkt.sel_20250625040959.pdf
# [PDF→TXT] D:\Project Penalaran Komputer\Data\raw\putusan_104_pid.c_2020_pn_jkt.sel_20250628173845.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 38
#      36         pdf_path = os.path.join(RAW_DIR, fn)
#      37         txt_path = os.path.join(RAW_DIR, fn[:-4] + ".txt")
# ---> 38         pdf_to_txt(pdf_path, txt_path)
#      39         print(f"[PDF→TXT] {pdf_path}")
#      41 # 2) Cleaning
#
# Cell In[1], line 11, in pdf_to_txt(pdf_path, txt_path)
#      10 def pdf_to_txt(pdf_path, txt_path):
# ---> 11     text = extract_text(pdf_path)
#      12     with open(txt_path, "w", encoding="utf-8") as f:
#      13         f.write(text)
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\high_level.py:184, in extract_text(pdf_file, password, page_numbers, maxpages, caching, codec, laparams)
#     175 interpreter = PDFPageInterpreter(rsrcmgr, device)
#     177 for page in PDFPage.get_pages(
#     178     fp,
#     179     page_numbers,
#    (...)
#     182     caching=caching,
#     183 ):
# --> 184     interpreter.process_page(page)
#     186 return output_string.getvalue()
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\pdfinterp.py:1210, in PDFPageInterpreter.process_page(self, page)
#    1208     ctm = (1, 0, 0, 1, -x0, -y0)
#    1209 self.device.begin_page(page, ctm)
# -> 1210 self.render_contents(page.resources, page.contents, ctm=ctm)
#    1211 self.device.end_page(page)
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\pdfinterp.py:1231, in PDFPageInterpreter.render_contents(self, resources, streams, ctm)
#    1229 self.init_resources(resources)
#    1230 self.init_state(ctm)
# -> 1231 self.execute(list_value(streams))
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\pdfinterp.py:1257, in PDFPageInterpreter.execute(self, streams)
#    1255     log.debug("exec: %s %r", name, args)
#    1256     if len(args) == nargs:
# -> 1257         func(*args)
#    1258 else:
#    1259     log.debug("exec: %s", name)
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\pdfinterp.py:1184, in PDFPageInterpreter.do_Do(self, xobjid_arg)
#    1182         resources = self.resources.copy()
#    1183     self.device.begin_figure(xobjid, bbox, matrix)
# -> 1184     interpreter.render_contents(
#    1185         resources,
#    1186         [xobj],
#    1187         ctm=mult_matrix(matrix, self.ctm),
#    1188     )
#    1189     self.device.end_figure(xobjid)
#    1190 elif subtype is LITERAL_IMAGE and "Width" in xobj and "Height" in xobj:
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\pdfinterp.py:1231, in PDFPageInterpreter.render_contents(self, resources, streams, ctm)
#    1229 self.init_resources(resources)
#    1230 self.init_state(ctm)
# -> 1231 self.execute(list_value(streams))
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\pdfinterp.py:1257, in PDFPageInterpreter.execute(self, streams)
#    1255     log.debug("exec: %s %r", name, args)
#    1256     if len(args) == nargs:
# -> 1257         func(*args)
#    1258 else:
#    1259     log.debug("exec: %s", name)
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\pdfinterp.py:1118, in PDFPageInterpreter.do_TJ(self, seq)
#    1116         raise PDFInterpreterError("No font specified!")
#    1117     return
# -> 1118 self.device.render_string(
#    1119     self.textstate,
#    1120     cast(PDFTextSeq, seq),
#    1121     self.graphicstate.ncs,
#    1122     self.graphicstate.copy(),
#    1123 )
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\pdfdevice.py:137, in PDFTextDevice.render_string(self, textstate, seq, ncs, graphicstate)
#     122     textstate.linematrix = self.render_string_vertical(
#     123         seq,
#     124         matrix,
#    (...)
#     134         graphicstate,
#     135     )
#     136 else:
# --> 137     textstate.linematrix = self.render_string_horizontal(
#     138         seq,
#     139         matrix,
#     140         textstate.linematrix,
#     141         font,
#     142         fontsize,
#     143         scaling,
#     144         charspace,
#     145         wordspace,
#     146         rise,
#     147         dxscale,
#     148         ncs,
#     149         graphicstate,
#     150     )
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\pdfdevice.py:177, in PDFTextDevice.render_string_horizontal(self, seq, matrix, pos, font, fontsize, scaling, charspace, wordspace, rise, dxscale, ncs, graphicstate)
#     175 if needcharspace:
#     176     x += charspace
# --> 177 x += self.render_char(
#     178     utils.translate_matrix(matrix, (x, y)),
#     179     font,
#     180     fontsize,
#     181     scaling,
#     182     rise,
#     183     cid,
#     184     ncs,
#     185     graphicstate,
#     186 )
#     187 if cid == 32 and wordspace:
#     188     x += wordspace
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\converter.py:253, in PDFLayoutAnalyzer.render_char(self, matrix, font, fontsize, scaling, rise, cid, ncs, graphicstate)
#     251 textwidth = font.char_width(cid)
#     252 textdisp = font.char_disp(cid)
# --> 253 item = LTChar(
#     254     matrix,
#     255     font,
#     256     fontsize,
#     257     scaling,
#     258     rise,
#     259     text,
#     260     textwidth,
#     261     textdisp,
#     262     ncs,
#     263     graphicstate,
#     264 )
#     265 self.cur_item.add(item)
#     266 return item.adv
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\layout.py:397, in LTChar.__init__(self, matrix, font, fontsize, scaling, rise, text, textwidth, textdisp, ncs, graphicstate)
#     395 if y1 < y0:
#     396     (y0, y1) = (y1, y0)
# --> 397 LTComponent.__init__(self, (x0, y0, x1, y1))
#     398 if font.is_vertical():
#     399     self.size = self.width
#
# File c:\Users\rifza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pdfminer\layout.py:145, in LTComponent.__init__(self, bbox)
#     144 def __init__(self, bbox: Rect) -> None:
# --> 145     LTItem.__init__(self)
#     146     self.set_bbox(bbox)
#
# KeyboardInterrupt:
